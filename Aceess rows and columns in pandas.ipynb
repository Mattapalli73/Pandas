# %%
import pandas as pd
df=pd.read_csv('pokemon_data.csv')
#print(df.columns)
#print(df.Name)
#print(df['Name'])
#print(df['Name'][0:2])
#print(df[ ['Name','Type 1','Type 1'][0:1]])
#print(df.iloc[1:0])
#print(df)
print(df.iloc[2,-1])
# Out:
# False

# %%
print(df.iloc[-1:0])
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []
